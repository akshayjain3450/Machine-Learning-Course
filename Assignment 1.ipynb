# %% [markdown]
# # Plotting of Error Function vs Parameter w1(slope)

# %% [markdown]
# Libraries

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# For the Linear Model Y = mX + C

# %%
m = 1
c = 0
x = np.linspace(1, 10, 11)
y = m * x + c
print(x)
print(y)
# Out:
# [ 1.   1.9  2.8  3.7  4.6  5.5  6.4  7.3  8.2  9.1 10. ]
# [ 1.   1.9  2.8  3.7  4.6  5.5  6.4  7.3  8.2  9.1 10. ]

# %%
plt.plot(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title(" Linear Model y = mx + c where c = 0 ")
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Initialisation

# %%
error = []
w0 = 0

# %% [markdown]
# Parameters

# %%
def generate_parameters():
    w1 = np.linspace(-5, 8, 11)
    return w1

# %% [markdown]
# Error Function $$ L =\sum_{i=1}^n w_1 * x^i + w_0 - y^i$$

# %%
def error_func():
    W1 = generate_parameters()
    for i in range(len(x)):
        e = (w0 + np.multiply(x,W1[i]) - y) ** 2
        e = sum(e)
        error.append(np.absolute(e))
    return error

# %% [markdown]
# # Plotting

# %%
x = generate_parameters()
y = error_func()
plt.plot(x,y)
plt.scatter(x,y, color = "black")
plt.xlabel("Parameter: w1 (slope)")
plt.ylabel("Error")
plt.title("Error vs w1 (slope) Graph")
plt.show()

# %% [markdown]
# # The minimum lies at w1 = 1 where the error = 0, as depicted by the graph
